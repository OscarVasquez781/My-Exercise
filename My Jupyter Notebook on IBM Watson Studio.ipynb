# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Oscar Vasquez**
# Aeronautical Engineer

# %% [markdown]
# *I am interested in data science because i want to be capable to analize maintenance data
# I am interested in data science because i want to improve my professional capabilities*

# %% [markdown]
# # The code will add to different numbers

# %%
2+1
# Out:
# 3

# %% [markdown]
# - Advantage of Data Science
# - Improving capabilities
#
# 1. Python
# 2. R
# 3. SQL
#
# IBM Watson Studio
# Watson Studio - IBM Cloudhttps://cloud.ibm.com › catalog › services › watson-stu...
